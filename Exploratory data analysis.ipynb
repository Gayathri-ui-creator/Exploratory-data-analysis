# %%
# Load the Titanic dataset and inspect the first few rows and data types

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
# Read the CSV file

# %%
df=pd.read_csv(r"C:\Users\venkatgayu\OneDrive\Desktop\jupyter notebook\Exploration data analysis\.ipynb_checkpoints\Titanic.csv")

# %%
df
# Out:
#      PassengerId  Pclass               Name     Sex  Age  SibSp  Parch  \
# 0              1       3       Allison Hill    male   17      4      2
# 1              2       1        Noah Rhodes    male   60      2      2
# 2              3       3    Angie Henderson    male   64      0      0
# 3              4       3      Daniel Wagner    male   35      4      0
# 4              5       1    Cristian Santos  female   70      0      3
# ..           ...     ...                ...     ...  ...    ...    ...
# 995          996       2      Brittany Ward    male   69      2      3
# 996          997       2     Edward Stanley  female   61      4      4
# 997          998       3  Christina Johnson    male   10      4      1
# 998          999       3       Edgar Miller    male   50      3      2
# 999         1000       1  Elizabeth Sanders    male    3      3      3
#
#                                    Ticket    Fare Embarked  Survived
# ...

# %%
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1000 non-null   int64
#  1   Pclass       1000 non-null   int64
#  2   Name         1000 non-null   object
#  3   Sex          1000 non-null   object
#  4   Age          1000 non-null   int64
#  5   SibSp        1000 non-null   int64
#  6   Parch        1000 non-null   int64
#  7   Ticket       1000 non-null   object
#  8   Fare         1000 non-null   float64
#  9   Embarked     1000 non-null   object
#  10  Survived     1000 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 86.1+ KB
#         PassengerId       Pclass            Name   Sex          Age  \
# count   1000.000000  1000.000000            1000  1000  1000.000000
# unique          NaN          NaN             995     2          NaN
# ...

# %%
# Show the head and data types for initial inspection

# %%
print(df.head())
print(df.dtypes)
# Out:
#    PassengerId  Pclass             Name     Sex  Age  SibSp  Parch  \
# 0            1       3     Allison Hill    male   17      4      2
# 1            2       1      Noah Rhodes    male   60      2      2
# 2            3       3  Angie Henderson    male   64      0      0
# 3            4       3    Daniel Wagner    male   35      4      0
# 4            5       1  Cristian Santos  female   70      0      3
#
#                                  Ticket    Fare Embarked  Survived
# 0  43d75413-a939-4bd1-a516-b0d47d3572cc  144.08        Q         1
# 1  6334fa2a-8b4b-47e7-a451-5ae01754bf08  249.04        S         0
# 2  61a66444-e2af-4629-9efb-336e2f546033   50.31        Q         1
# 3  0b6c03c8-721e-4419-afc3-e6495e911b91  235.20        C         1
# 4  436e3c49-770e-49db-b092-d40143675d58  160.17        C         1
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age              int64
# SibSp            int64
# ...

# %%
# Data Cleaning: Check for missing values, duplicates, and basic statistics

# %%
print(df.isnull().sum())
print(df.duplicated().sum())
print(df.describe(include='all'))
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Survived       0
# dtype: int64
# 0
#         PassengerId       Pclass            Name   Sex          Age  \
# count   1000.000000  1000.000000            1000  1000  1000.000000
# unique          NaN          NaN             995     2          NaN
# top             NaN          NaN  Michael Miller  male          NaN
# freq            NaN          NaN               2   527          NaN
# mean     500.500000     1.964000             NaN   NaN    38.458000
# std      288.819436     0.820596             NaN   NaN    23.103723
# min        1.000000     1.000000             NaN   NaN     1.000000
# 25%      250.750000     1.000000             NaN   NaN    19.000000
# 50%      500.500000     2.000000             NaN   NaN    36.500000
# ...

# %%
# EDA: Visualize distributions of Age, Fare, Pclass, Sex, and Survived

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# %%
# Age distribution

# %%
sns.histplot(df['Age'], bins=30, kde=True, ax=axes[0,0])
axes[0,0].set_title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
# Fare distribution

# %%
sns.histplot(df['Fare'], bins=30, kde=True, ax=axes[0,1])
axes[0,1].set_title('Fare Distribution')
# Out:
# Text(0.5, 1.0, 'Fare Distribution')

# %%
# Pclass distribution

# %%
sns.countplot(x='Pclass', data=df, ax=axes[0,2])
axes[0,2].set_title('Passenger Class Distribution')
# Out:
# Text(0.5, 1.0, 'Passenger Class Distribution')

# %%
# Sex distribution

# %%
sns.countplot(x='Sex', data=df, ax=axes[1,0])
axes[1,0].set_title('Sex Distribution')
# Out:
# Text(0.5, 1.0, 'Sex Distribution')

# %%
# Survived distribution

# %%
sns.countplot(x='Survived', data=df, ax=axes[1,1])
axes[1,1].set_title('Survival Distribution')
# Out:
# Text(0.5, 1.0, 'Survival Distribution')

# %%
# Embarked distribution

# %%
sns.countplot(x='Embarked', data=df, ax=axes[1,2])
axes[1,2].set_title('Port of Embarkation Distribution')
# Out:
# Text(0.5, 1.0, 'Port of Embarkation Distribution')

# %%
plt.tight_layout()
plt.show()

# %%
print('Displayed distributions of key features.')
# Out:
# Displayed distributions of key features.

# %%
# Survival rate by Sex and Pclass

# %%
survival_by_sex = df.groupby('Sex')['Survived'].mean()
survival_by_class = df.groupby('Pclass')['Survived'].mean()

# %%
# Plot survival rate by Sex

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.barplot(x=survival_by_sex.index, y=survival_by_sex.values)
plt.title('Survival Rate by Sex')
plt.ylabel('Survival Rate')
plt.xlabel('Sex')
# Out:
# Text(0.5, 0, 'Sex')

# %%
# Plot survival rate by Pclass

# %%
plt.subplot(1,2,2)
sns.barplot(x=survival_by_class.index, y=survival_by_class.values)
plt.title('Survival Rate by Passenger Class')
plt.ylabel('Survival Rate')
plt.xlabel('Pclass')
# Out:
# Text(0.5, 0, 'Pclass')

# %%
plt.tight_layout()
plt.show()

# %%
print('Displayed survival rates by sex and class.')
# Out:
# Displayed survival rates by sex and class.

# %%
# Visualize Age and Fare distributions by Survival

# %%
plt.figure(figsize=(14,6))

# %%
# Age vs Survived

# %%
plt.subplot(1,2,1)
sns.histplot(data=df, x='Age', hue='Survived', bins=30, kde=True, element='step', stat='density', common_norm=False)
plt.title('Age Distribution by Survival')
# Out:
# Text(0.5, 1.0, 'Age Distribution by Survival')

# %%
# Fare vs Survived

# %%
plt.subplot(1,2,2)
sns.histplot(data=df, x='Fare', hue='Survived', bins=30, kde=True, element='step', stat='density', common_norm=False)
plt.title('Fare Distribution by Survival')
# Out:
# Text(0.5, 1.0, 'Fare Distribution by Survival')

# %%
plt.tight_layout()
plt.show()

# %%
print('Displayed histograms for Age and Fare distributions by survival.')
# Out:
# Displayed histograms for Age and Fare distributions by survival.

# %%
# Scatterplot: Age vs Fare colored by Survival

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Age', y='Fare', hue='Survived', data=df, alpha=0.7)
plt.title('Age vs Fare by Survival')
plt.show()

# %%
print('Displayed scatterplot for Age and Fare by Survival.')
# Out:
# Displayed scatterplot for Age and Fare by Survival.

# %%
# Boxplots for Age and Fare by Survival

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
sns.boxplot(x='Survived', y='Age', data=df)
plt.title('Age by Survival')
plt.subplot(1,2,2)
sns.boxplot(x='Survived', y='Fare', data=df)
plt.title('Fare by Survival')
plt.tight_layout()
plt.show()

# %%
print('Displayed boxplots for Age and Fare by Survival.')
# Out:
# Displayed boxplots for Age and Fare by Survival.

# %%
# Survival rate by Embarked

# %%
survival_by_embarked = df.groupby('Embarked')['Survived'].mean()

# %%
# Family size feature

# %%
df['FamilySize'] = df['SibSp'] + df['Parch']
survival_by_familysize = df.groupby('FamilySize')['Survived'].mean()

# %%
# Plot survival rate by Embarked

# %%
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
sns.barplot(x=survival_by_embarked.index, y=survival_by_embarked.values)
plt.title('Survival Rate by Port of Embarkation')
plt.ylabel('Survival Rate')
plt.xlabel('Embarked')
# Out:
# Text(0.5, 0, 'Embarked')

# %%
# Plot survival rate by Family Size

# %%
plt.subplot(1,2,2)
sns.lineplot(x=survival_by_familysize.index, y=survival_by_familysize.values, marker='o')
plt.title('Survival Rate by Family Size')
plt.ylabel('Survival Rate')
plt.xlabel('Family Size')
# Out:
# Text(0.5, 0, 'Family Size')

# %%
plt.tight_layout()
plt.show()

# %%
print('Displayed survival rates by port of embarkation and family size.')
# Out:
# Displayed survival rates by port of embarkation and family size.

# %%
# Exploratory Data Analysis (EDA) for Titanic.csv

# %%
# 1. Basic info and summary statistics

# %%
print('--- DataFrame Info ---')
df.info()
print('\
--- Summary Statistics ---')
print(df.describe(include='all'))
# Out:
# --- DataFrame Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1000 non-null   int64
#  1   Pclass       1000 non-null   int64
#  2   Name         1000 non-null   object
#  3   Sex          1000 non-null   object
#  4   Age          1000 non-null   int64
#  5   SibSp        1000 non-null   int64
#  6   Parch        1000 non-null   int64
#  7   Ticket       1000 non-null   object
#  8   Fare         1000 non-null   float64
#  9   Embarked     1000 non-null   object
#  10  Survived     1000 non-null   int64
#  11  FamilySize   1000 non-null   int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 93.9+ KB
# --- Summary Statistics ---
#         PassengerId       Pclass            Name   Sex          Age  \
# count   1000.000000  1000.000000            1000  1000  1000.000000
# ...

# %%
# 2. Value counts for categorical features

# %%
print('\
--- Value Counts: Sex ---')
print(df['Sex'].value_counts())
print('\
--- Value Counts: Pclass ---')
print(df['Pclass'].value_counts())
print('\
--- Value Counts: Embarked ---')
print(df['Embarked'].value_counts())
print('\
--- Value Counts: Survived ---')
print(df['Survived'].value_counts())
# Out:
# --- Value Counts: Sex ---
# Sex
# male      527
# female    473
# Name: count, dtype: int64
# --- Value Counts: Pclass ---
# Pclass
# 1    355
# 2    326
# 3    319
# Name: count, dtype: int64
# --- Value Counts: Embarked ---
# Embarked
# Q    362
# C    328
# S    310
# Name: count, dtype: int64
# --- Value Counts: Survived ---
# Survived
# 0    508
# 1    492
# Name: count, dtype: int64

# %%
# Visualize pairwise relationships

# %%
import seaborn as sns
sns.pairplot(df[['Age', 'Fare', 'Pclass', 'Survived', 'FamilySize']], hue='Survived', diag_kind='kde')
plt.suptitle('Pairplot of Numerical Features by Survival', y=1.02)
plt.show()

# %%
# Correlation heatmap

# %%
plt.figure(figsize=(8,6))
corr = df[['Age', 'Fare', 'Pclass', 'SibSp', 'Parch', 'FamilySize', 'Survived']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
print('Displayed pairplot and correlation heatmap.')
# Out:
# Displayed pairplot and correlation heatmap.

# %%
# Insights and Observations

# %%
#- **Socio-economic status (class, fare), gender, and age were the most important factors in survival.
#- **Females and 1st class passengers had much higher survival rates.
#- **Survivors tend to be younger and paid higher fares.
#- **Family size: both very small and very large families had lower survival rates.
#- **The data supports the historical narrative: women, children, and wealthier passengers had the best chances of survival.
